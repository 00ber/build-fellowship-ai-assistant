# %% [markdown]
# # Workshop 6: Memory & Conversations for Analytics Code Agents
#
# In Workshop 5, we built a coding agent that can do EDA by generating Python and executing it safely.
#
# In Workshop 6, we'll make the assistant **conversational** by adding:
#
# - **Agent/session state** (tables, `table_id`s, active table)
# - **Chat history** (window/buffer)
# - **Summarization** (so history scales)
# - A simple pattern for **long-term memory** (persist across sessions)

# %% [markdown]
# ## Today's agenda
#
# 1) Recap: the Workshop 5 code agent
# 2) Why follow-ups break (the memory problem)
# 3) Add **agent/session state** (tables + active table)
# 4) Add **chat history** (window/buffer)
# 5) Make it scale (summary + buffer)
# 6) Put it all together (multi-turn loop)
# 7) Long-term memory (concept + tiny persistence demo)
# 8) Pitfalls & best practices

# %%
# Core imports
import os
import json
import uuid
import ast
import io
import contextlib
from dataclasses import dataclass, field
from pathlib import Path
from typing import Any, Dict, List, Literal, Optional, Tuple

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from utils.display import heading, output_box, compare_table, separator, llm_response

# OpenAI client
from openai import OpenAI
client = OpenAI()

MODEL = "gpt-4o-mini"

# %% [markdown]
# ## Setup: Load data & initialize the store
#
# This is the same Pokémon dataset and analytics store from Workshop 5. We load it, normalize column names, and set up the table store.

# %%
DATA_PATH = "./data/Pokemon.csv"

df_raw = pd.read_csv(DATA_PATH)

df = df_raw.copy()
df.columns = (
    df.columns
      .str.replace(" ", "_", regex=False)
      .str.replace(".", "", regex=False)
      .str.lower()
)

heading("Dataset loaded", level=3)
output_box(
    f"Path: {DATA_PATH}\nRows: {df.shape[0]}\nColumns: {df.shape[1]}",
    label="✅ Ready",
    style="success",
)
output_box(", ".join(df.columns.tolist()), label="Columns", style="info")
df.head(5)
# Out:
# ### Dataset loaded
#     <div style="background: #F0FDF4; border-left: 4px solid #DCFCE7; padding: 12px 16px; border-radius: 4px; margin: 8px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#         <div style="font-weight: 600; color: #15803D; margin-bottom: 4px;">✅ Ready</div>
#         <pre style="margin: 0; white-space: pre-wrap; font-size: 13px; line-height: 1.5; color: #374151;">Path: ./data/Pokemon.csv
# Rows: 800
# Columns: 13</pre>
#     </div>
#     <div style="background: #EFF6FF; border-left: 4px solid #DBEAFE; padding: 12px 16px; border-radius: 4px; margin: 8px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#         <div style="font-weight: 600; color: #1D4ED8; margin-bottom: 4px;">Columns</div>
#         <pre style="margin: 0; white-space: pre-wrap; font-size: 13px; line-height: 1.5; color: #374151;">#, name, type_1, type_2, total, hp, attack, defense, sp_atk, sp_def, speed, generation, legendary</pre>
# ...

# %%
# ─────────────────────────────────────────────
# State: tables in a tiny store
# ─────────────────────────────────────────────

@dataclass
class Table:
    table_id: str
    name: str
    df: pd.DataFrame

@dataclass
class AnalyticsStore:
    tables: Dict[str, Table] = field(default_factory=dict)
    active_table_id: Optional[str] = None

    def put(self, df: pd.DataFrame, name: str, *, set_active: bool = True) -> str:
        table_id = f"tbl_{uuid.uuid4().hex[:8]}"
        self.tables[table_id] = Table(table_id=table_id, name=name, df=df)
        if set_active:
            self.active_table_id = table_id
        return table_id

    def get(self, table_id: Optional[str] = None) -> Table:
        tid = table_id or self.active_table_id
        if tid is None or tid not in self.tables:
            raise KeyError(f"Unknown table_id: {tid}. Call list_tables() to see available tables.")
        return self.tables[tid]

    def set_active(self, table_id: str) -> None:
        if table_id not in self.tables:
            raise KeyError(f"Unknown table_id: {table_id}")
        self.active_table_id = table_id

    def list(self) -> List[Dict[str, Any]]:
        out = []
        for tid, t in self.tables.items():
            out.append({
                "table_id": tid,
                "name": t.name,
                "rows": int(t.df.shape[0]),
                "cols": int(t.df.shape[1]),
                "active": (tid == self.active_table_id),
            })
        return out

    def reset(self, keep_base: bool = True):
        """Reset to just the base table (useful between demo sections)."""
        if keep_base and self.tables:
            first_tid = next(iter(self.tables))
            first = self.tables[first_tid]
            self.tables = {first_tid: first}
            self.active_table_id = first_tid
        else:
            self.tables = {}
            self.active_table_id = None


# JSON-safe helpers
def _to_jsonable(x: Any) -> Any:
    if x is None:
        return None
    if isinstance(x, (str, int, bool)):
        return x
    if isinstance(x, float):
        return None if (np.isnan(x) or np.isinf(x)) else x
    if isinstance(x, (np.integer,)):
        return int(x)
    if isinstance(x, (np.floating,)):
        fx = float(x)
        return None if (np.isnan(fx) or np.isinf(fx)) else fx
    if isinstance(x, (np.bool_,)):
        return bool(x)
    if isinstance(x, (pd.Timestamp,)):
        return x.isoformat()
    if isinstance(x, (list, tuple)):
        return [_to_jsonable(v) for v in x]
    if isinstance(x, dict):
        return {str(k): _to_jsonable(v) for k, v in x.items()}
    if x is pd.NA:
        return None
    return str(x)

def _safe_json(obj: Any) -> str:
    return json.dumps(_to_jsonable(obj), indent=2, ensure_ascii=False, allow_nan=False)


# Initialize
store = AnalyticsStore()
pokemon_table_id = store.put(df, name="pokemon", set_active=True)

heading("Store initialized", level=3)
output_box(
    f"Active table: {store.get().name} ({store.get().table_id})",
    label="✅ AnalyticsStore",
    style="success",
)
# Out:
# ### Store initialized
#     <div style="background: #F0FDF4; border-left: 4px solid #DCFCE7; padding: 12px 16px; border-radius: 4px; margin: 8px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#         <div style="font-weight: 600; color: #15803D; margin-bottom: 4px;">✅ AnalyticsStore</div>
#         <pre style="margin: 0; white-space: pre-wrap; font-size: 13px; line-height: 1.5; color: #374151;">Active table: pokemon (tbl_6ba85378)</pre>
#     </div>

# %% [markdown]
# ### Tools from Workshop 5
#
# These are the same composable analytics tools from Workshop 5.

# %%
# ─────────────────────────────────────────────
# Tool helpers
# ─────────────────────────────────────────────

FilterOp = Literal["eq", "ne", "lt", "lte", "gt", "gte", "contains", "in"]
LogicOp = Literal["and", "or"]
AggOp = Literal["count", "sum", "mean", "median", "min", "max"]

def _error(msg: str) -> Dict[str, Any]:
    return {"ok": False, "summary": msg, "data": None}

def _ok(summary: str, data: Any = None) -> Dict[str, Any]:
    return {"ok": True, "summary": summary, "data": _to_jsonable(data)}

def require_ok(res: Dict[str, Any]) -> Dict[str, Any]:
    if not res.get("ok"):
        raise RuntimeError(res.get("summary") or "Tool failed")
    return res

def _check_columns(df: pd.DataFrame, cols: List[str]) -> Optional[str]:
    missing = [c for c in cols if c not in df.columns]
    if missing:
        return f"Unknown column(s): {missing}. Available: {df.columns.tolist()}"
    return None

# ─────────────────────────────────────────────
# Tools
# ─────────────────────────────────────────────

def list_tables() -> Dict[str, Any]:
    return _ok("Tables in store.", store.list())

def set_active_table(table_id: str) -> Dict[str, Any]:
    try:
        store.set_active(table_id)
        t = store.get(table_id)
        return _ok(f"Active table set to '{t.name}' ({t.table_id}).")
    except Exception as e:
        return _error(str(e))

def describe_table(table_id: Optional[str] = None) -> Dict[str, Any]:
    try:
        t = store.get(table_id)
        df = t.df
        schema = [{"name": c, "dtype": str(df[c].dtype)} for c in df.columns]
        numeric = df.select_dtypes(include=["number"]).describe().T.reset_index().rename(columns={"index": "column"})
        out = {
            "table_id": t.table_id,
            "name": t.name,
            "shape": [int(df.shape[0]), int(df.shape[1])],
            "columns": schema,
            "numeric_summary_preview": numeric.head(12).to_dict(orient="records"),
        }
        return _ok(f"Described table '{t.name}'.", out)
    except Exception as e:
        return _error(str(e))

def preview_table(table_id: Optional[str] = None, n: int = 10) -> Dict[str, Any]:
    try:
        t = store.get(table_id)
        n = max(1, min(int(n), 25))
        return _ok(f"Previewed {n} rows of '{t.name}'.", {"rows": t.df.head(n).to_dict(orient="records")})
    except Exception as e:
        return _error(str(e))

def filter_table(
    filters: List[Dict[str, Any]],
    logic: LogicOp = "and",
    table_id: Optional[str] = None,
    new_table_name: str = "filtered",
    *,
    set_active: bool = True,
) -> Dict[str, Any]:
    try:
        t = store.get(table_id)
        df = t.df
        cols = [f.get("column") for f in filters if f.get("column")]
        err = _check_columns(df, cols)
        if err:
            return _error(err)

        masks = []
        for f in filters:
            col, op, val = f["column"], f["op"], f.get("value")
            s = df[col]
            if   op == "eq":       m = s == val
            elif op == "ne":       m = s != val
            elif op == "lt":       m = s < val
            elif op == "lte":      m = s <= val
            elif op == "gt":       m = s > val
            elif op == "gte":      m = s >= val
            elif op == "contains": m = s.astype(str).str.contains(str(val), case=False, na=False)
            elif op == "in":
                if not isinstance(val, list):
                    return _error("For op='in', value must be a list.")
                m = s.isin(val)
            else:
                return _error(f"Unknown op: {op}")
            masks.append(m)

        if not masks:
            return _error("No filters provided.")

        combined = masks[0]
        for m in masks[1:]:
            combined = (combined & m) if logic == "and" else (combined | m)

        out_df = df[combined].copy()
        new_id = store.put(out_df, name=new_table_name, set_active=set_active)
        return _ok(
            f"Filtered '{t.name}' → {out_df.shape[0]} row(s). Saved as {new_id}.",
            {"table_id": new_id, "name": new_table_name, "rows": out_df.head(10).to_dict(orient="records")},
        )
    except Exception as e:
        return _error(str(e))

def groupby_aggregate(
    group_by: str,
    metric: str,
    agg: AggOp = "mean",
    table_id: Optional[str] = None,
    top_n: int = 10,
    new_table_name: str = "grouped",
    *,
    set_active: bool = True,
) -> Dict[str, Any]:
    try:
        t = store.get(table_id)
        df = t.df
        err = _check_columns(df, [group_by, metric])
        if err:
            return _error(err)

        if agg == "count":
            g = df.groupby(group_by)[metric].count().reset_index(name=f"{metric}_{agg}")
        else:
            g = df.groupby(group_by)[metric].agg(agg).reset_index(name=f"{metric}_{agg}")

        g = g.sort_values(by=g.columns[-1], ascending=False)
        top_n = max(1, min(int(top_n), 50))
        g_top = g.head(top_n).copy()
        new_id = store.put(g_top, name=new_table_name, set_active=set_active)
        return _ok(
            f"Grouped '{t.name}' by '{group_by}', agg={agg}('{metric}'). Saved as {new_id}.",
            {"table_id": new_id, "name": new_table_name, "rows": g_top.to_dict(orient="records")},
        )
    except Exception as e:
        return _error(str(e))

def plot_bar(table_id: str, x: str, y: str, title: str = "") -> Dict[str, Any]:
    try:
        t = store.get(table_id)
        df = t.df
        err = _check_columns(df, [x, y])
        if err:
            return _error(err)
        plt.figure(figsize=(8, 4))
        plt.bar(df[x].astype(str), df[y])
        plt.xticks(rotation=45, ha="right")
        plt.title(title or f"{y} by {x}")
        plt.tight_layout()
        plt.show()
        return _ok(f"Rendered bar chart from table '{t.name}'.")
    except Exception as e:
        return _error(str(e))

def scatter_plot(x: str, y: str, table_id: Optional[str] = None, title: str = "") -> Dict[str, Any]:
    try:
        t = store.get(table_id)
        df = t.df
        err = _check_columns(df, [x, y])
        if err:
            return _error(err)
        plt.figure(figsize=(6, 4))
        plt.scatter(df[x], df[y], alpha=0.7)
        plt.xlabel(x); plt.ylabel(y)
        plt.title(title or f"{y} vs {x}")
        plt.tight_layout()
        plt.show()
        return _ok(f"Rendered scatter plot: {y} vs {x}.")
    except Exception as e:
        return _error(str(e))

def histogram(column: str, table_id: Optional[str] = None, bins: int = 20, title: str = "") -> Dict[str, Any]:
    try:
        t = store.get(table_id)
        df = t.df
        err = _check_columns(df, [column])
        if err:
            return _error(err)
        bins = max(5, min(int(bins), 60))
        plt.figure(figsize=(6, 4))
        plt.hist(df[column].dropna(), bins=bins)
        plt.title(title or f"Histogram of {column}")
        plt.tight_layout()
        plt.show()
        return _ok(f"Rendered histogram: {column}.")
    except Exception as e:
        return _error(str(e))

def get_df(table_id: Optional[str] = None) -> pd.DataFrame:
    return store.get(table_id).df.copy()

def save_df(df: pd.DataFrame, name: str = "derived", *, set_active: bool = False) -> str:
    return store.put(df.copy(), name=name, set_active=set_active)

heading("Tools ready", level=3)
output_box("All analytics tools from Workshop 5 are loaded.", label="✅ Tools", style="success")
# Out:
# ### Tools ready
#     <div style="background: #F0FDF4; border-left: 4px solid #DCFCE7; padding: 12px 16px; border-radius: 4px; margin: 8px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#         <div style="font-weight: 600; color: #15803D; margin-bottom: 4px;">✅ Tools</div>
#         <pre style="margin: 0; white-space: pre-wrap; font-size: 13px; line-height: 1.5; color: #374151;">All analytics tools from Workshop 5 are loaded.</pre>
#     </div>

# %% [markdown]
# ### Safe executor & coding agent from Workshop 5
#
# The executor validates generated code via AST checks, then runs it in a sandboxed `exec` environment. The agent loop calls the LLM, runs code, and retries on errors.
#
# > **New in this workshop:** `run_code_agent` now accepts optional `state_context` and `history_context` strings that get injected as system messages before the user query. This is how we'll add memory.

# %%
# ─────────────────────────────────────────────
# Safe executor
# ─────────────────────────────────────────────

from pydantic import BaseModel, Field

SAFE_BUILTINS = {
    "abs": abs, "bool": bool, "dict": dict, "enumerate": enumerate, "float": float,
    "int": int, "len": len, "list": list, "max": max, "min": min, "print": print,
    "range": range, "round": round, "sorted": sorted, "str": str, "sum": sum, "zip": zip,
    "type": type, "isinstance": isinstance,
}

DISALLOWED_NODES = (
    ast.Import, ast.ImportFrom,
    ast.With, ast.AsyncWith,
    ast.Try,
    ast.While,
    ast.FunctionDef, ast.AsyncFunctionDef, ast.ClassDef,
    ast.Lambda,
    ast.Global, ast.Nonlocal,
)

DISALLOWED_NAMES = {
    "open", "exec", "eval", "compile", "__import__",
    "os", "sys", "subprocess", "pathlib", "shutil",
    "socket", "requests", "http", "urllib",
}

def validate_code_ast(code: str) -> Tuple[bool, str]:
    try:
        tree = ast.parse(code)
    except SyntaxError as e:
        return False, f"SyntaxError: {e}"
    for node in ast.walk(tree):
        if isinstance(node, DISALLOWED_NODES):
            return False, f"Disallowed syntax: {type(node).__name__}"
        if isinstance(node, ast.Name) and node.id in DISALLOWED_NAMES:
            return False, f"Disallowed name: {node.id}"
        if isinstance(node, ast.Attribute) and node.attr.startswith("__"):
            return False, f"Disallowed attribute: {node.attr}"
    return True, "ok"


def make_exec_env() -> Dict[str, Any]:
    def _save_df(df, name: str = "derived", set_active: bool = False) -> str:
        return save_df(df, name=name, set_active=set_active)

    return {
        "__builtins__": SAFE_BUILTINS,
        "pd": pd, "np": np,
        "pokemon_table_id": pokemon_table_id,
        "get_df": get_df, "save_df": _save_df,
        "require_ok": require_ok,
        "filter_table": filter_table,
        "groupby_aggregate": groupby_aggregate,
        "plot_bar": plot_bar,
        "scatter_plot": scatter_plot,
        "histogram": histogram,
        "describe_table": describe_table,
        "list_tables": list_tables,
        "set_active_table": set_active_table,
    }


def execute_python(code: str, env: Dict[str, Any], local_vars: Dict[str, Any]) -> Dict[str, Any]:
    ok, msg = validate_code_ast(code)
    if not ok:
        return {"ok": False, "stdout": "", "error": msg, "created_table_ids": []}

    before = set(store.tables.keys())
    stdout_buf = io.StringIO()
    err = None

    with contextlib.redirect_stdout(stdout_buf):
        try:
            exec(code, env, local_vars)
        except Exception as e:
            err = f"{type(e).__name__}: {e}"

    after = set(store.tables.keys())
    created = sorted(after - before)

    # Roll back tables created during a failed step to avoid state pollution
    if err:
        for tid in created:
            del store.tables[tid]
        created = []

    return {
        "ok": err is None,
        "stdout": stdout_buf.getvalue(),
        "error": err,
        "created_table_ids": created,
    }


# ─────────────────────────────────────────────
# Structured output schema
# ─────────────────────────────────────────────

class CodeStep(BaseModel):
    plan: str = Field(..., description="1–3 short sentences describing what you will do next.")
    code: str = Field("", description="Python code to execute. Can be empty if no code is needed this step.")
    done: bool = Field(..., description="True if you are ready to answer the user.")
    final_answer: str = Field("", description="User-facing answer. Required when done=true.")


# ─────────────────────────────────────────────
# System prompt (from Workshop 5, unchanged)
# ─────────────────────────────────────────────

SYSTEM_PROMPT_CODE_AGENT = """
You are a coding agent that helps a student do exploratory data analysis (EDA).

You MUST output JSON with exactly these fields:
- plan: 1–3 short sentences
- code: Python code to execute (NO markdown, NO backticks)
- done: boolean
- final_answer: string (REQUIRED when done=true)

When to set done:
- done=false: you are still computing / creating artifacts / plotting. Print intermediate values you will need.
- done=true: provide final_answer. code may be empty if no computation is needed.

============================================================
Environment (what exists in code)
============================================================
You can use:
- pd, np
- pokemon_table_id: str  (table_id for the full Pokémon table)

Data access:
- get_df(table_id: str | None = None) -> pandas.DataFrame
  Returns a COPY of the table.

- save_df(df: pandas.DataFrame, name: str, set_active: bool = False) -> str
  Saves a new table and returns a table_id like "tbl_1234abcd".

Introspection:
- preview_table(table_id: str | None = None, n: int = 10) -> None
- describe_table(table_id: str | None = None) -> dict
- list_tables() -> dict

============================================================
Tool Results Convention (IMPORTANT)
============================================================
Composable tools return dicts shaped like:
  {"ok": bool, "summary": str, "data": ...}

Helper:
- require_ok(res_dict: dict) -> dict
  Returns res_dict if ok=True; otherwise raises RuntimeError(summary).

Golden rule:
- For tools that create a new table (filter_table, groupby_aggregate),
  the new table_id is ALWAYS at: result["data"]["table_id"]

============================================================
Composable Tools (use these for safe composition)
============================================================

1) filter_table(...) -> dict
Signature:
- filter_table(
    filters: list[dict],
    logic: "and" | "or" = "and",
    table_id: str | None = None,
    new_table_name: str = "filtered",
    set_active: bool = True
  ) -> dict

Filters format (REQUIRED):
Each filter MUST be:
  {"column": "<col>", "op": "<op>", "value": <value>}

Valid ops:
  eq, ne, lt, lte, gt, gte, contains, in

Example (Fire in either type_1 or type_2):
  filters=[
    {"column":"type_1","op":"eq","value":"Fire"},
    {"column":"type_2","op":"eq","value":"Fire"},
  ], logic="or"

Common mistakes to avoid:
- DO NOT pass filters as a dict like {"type_1":"Fire"} (will fail).
- DO NOT rely on the active table; always pass table_id= explicitly.

On success:
- result["data"]["table_id"] is the filtered table_id.

------------------------------------------------------------

2) groupby_aggregate(...) -> dict
Signature:
- groupby_aggregate(
    group_by: str,
    metric: str,
    agg: "count"|"sum"|"mean"|"median"|"min"|"max" = "mean",
    table_id: str | None = None,
    top_n: int = 10,
    new_table_name: str = "grouped",
    set_active: bool = True
  ) -> dict

On success:
- result["data"]["table_id"] is the grouped table_id.
- result["data"]["rows"] is a list of row dicts with the aggregated values.
- the aggregated column name is ALWAYS f"{metric}_{agg}"
  Example: metric="bulkiness", agg="mean" -> "bulkiness_mean"
  To read the value: result["data"]["rows"][0]["bulkiness_mean"]

Common mistakes to avoid:
- DO NOT use result["table_id"] or result["new_table_id"] (wrong).
- DO NOT group by columns that do not exist in the chosen table.

------------------------------------------------------------

3) plot_bar(...) -> dict
Signature:
- plot_bar(table_id: str, x: str, y: str, title: str = "") -> dict

Behavior:
- Plots a bar chart from an existing table using column names.

Common mistakes to avoid:
- DO NOT pass pandas Series/arrays.
- x and y must be column names in the specified table_id.

------------------------------------------------------------

4) histogram(...) -> dict
Signature:
- histogram(column: str, table_id: str | None = None, bins: int = 20, title: str = "") -> dict

Behavior:
- Plots a histogram of a single numeric column.

------------------------------------------------------------

5) scatter_plot(...) -> dict
Signature:
- scatter_plot(x: str, y: str, table_id: str | None = None, title: str = "") -> dict

Behavior:
- Scatter plot of two numeric columns.

============================================================
Critical Invariants (read carefully)
============================================================
1) get_df returns a COPY.
   If you add derived columns, tools will NOT see them until you save_df.
   Pattern:
     df = get_df(table_id=...)
     df["new_col"] = ...
     tid = save_df(df, name="...", set_active=False)
     # use tid in tools

2) table_id vs name:
   - save_df returns a table_id string (tbl_...)
   - new_table_name is a label only
   - NEVER pass names where a table_id is required

3) require_ok is ONLY for dict-returning tools.
   - OK: require_ok(filter_table(...))
   - OK: require_ok(groupby_aggregate(...))
   - OK: require_ok(plot_bar(...))
   - NOT OK: require_ok(save_df(...))  # save_df returns a string

4) Do not rely on active table defaults.
   Always pass table_id explicitly to filter_table, groupby_aggregate, plot_bar, get_df.

5) Bare expressions do not display in this sandbox.
   If you need a value for final_answer, print it (or compute it directly into final_answer).

============================================================
Generated code samples:
============================================================

Example A: filter + row count
  fire = require_ok(filter_table(
      filters=[
        {"column":"type_1","op":"eq","value":"Fire"},
        {"column":"type_2","op":"eq","value":"Fire"},
      ],
      logic="or",
      table_id=pokemon_table_id,
      new_table_name="fire_pokemon",
      set_active=False,
  ))
  fire_tid = fire["data"]["table_id"]
  n = len(get_df(table_id=fire_tid))
  print("ROWS:", n)
  done = True
  final_answer = f"fire_pokemon has {n} rows."

Example B: derived metric + groupby + plot
  df = get_df(table_id=pokemon_table_id)
  df["bulkiness"] = (df["hp"] + df["defense"]) / df["speed"]
  tid = save_df(df, name="pokemon_with_bulkiness", set_active=False)

  agg = require_ok(groupby_aggregate(
      group_by="generation",
      metric="bulkiness",
      agg="mean",
      table_id=tid,
      top_n=6,
      new_table_name="bulkiness_by_gen",
      set_active=False,
  ))
  agg_tid = agg["data"]["table_id"]

  require_ok(plot_bar(
      table_id=agg_tid,
      x="generation",
      y="bulkiness_mean",
      title="Top 6 generations by mean bulkiness",
  ))

  done = True
  final_answer = "Computed bulkiness and plotted top generations by mean bulkiness."

============================================================
Sandbox restrictions
============================================================
- NO imports
- NO def/class/lambda
- NO while
- NO dunder attributes (obj.__something__)

Keep code short and readable.
"""


# ─────────────────────────────────────────────
# LLM call helper
# ─────────────────────────────────────────────

def call_llm(
    *,
    model: str,
    messages: List[Dict[str, Any]],
    response_model: type[BaseModel],
) -> BaseModel:
    resp = client.responses.parse(
        model=model,
        input=messages,
        text_format=response_model,
        temperature=0,
    )
    return resp.output_parsed


# ─────────────────────────────────────────────
# Trace renderer
# ─────────────────────────────────────────────

def render_code_trace(trace: List[Dict[str, Any]]) -> None:
    if not trace:
        output_box("No trace.", label="Trace", style="warning")
        return
    for i, step in enumerate(trace, start=1):
        heading(f"Step {i}", level=4)
        output_box(step.get("plan",""), label="Plan", style="info")
        if step.get("code","").strip():
            output_box(step["code"], label="Code", style="success")
        if step.get("stdout"):
            output_box(step["stdout"], label="stdout", style="info")
        if step.get("error"):
            output_box(step["error"], label="error", style="error")
        output_box(str(step.get("done")), label="done", style="info")
        if step.get("final_answer","").strip():
            output_box(step["final_answer"], label="final_answer", style="success")


# ─────────────────────────────────────────────
# Agent loop
#
# NEW vs Workshop 5: accepts state_context and
# history_context for memory injection.
# ─────────────────────────────────────────────

def run_code_agent(
    question: str,
    *,
    model: str = MODEL,
    max_steps: int = 6,
    state_context: Optional[str] = None,
    history_context: Optional[str] = None,
) -> Dict[str, Any]:
    """Run the code agent. Returns {"final": str, "trace": list}."""

    messages: List[Dict[str, Any]] = [{"role": "developer", "content": SYSTEM_PROMPT_CODE_AGENT}]

    # ← THIS IS THE NEW PART: inject memory as additional system messages
    if state_context and state_context.strip():
        messages.append({"role": "developer", "content": state_context.strip()})
    if history_context and history_context.strip():
        messages.append({"role": "developer", "content": history_context.strip()})

    messages.append({"role": "user", "content": question})

    trace: List[Dict[str, Any]] = []
    env = make_exec_env()
    local_vars = {}  # persists across steps so variables survive between code blocks

    for _ in range(max_steps):
        parsed = call_llm(model=model, messages=messages, response_model=CodeStep)
        if parsed is None:
            return {"final": "Could not parse CodeStep from model output.", "trace": trace}

        if (parsed.code or "").strip():
            result = execute_python(parsed.code, env=env, local_vars=local_vars)
        else:
            result = {"ok": True, "stdout": "", "error": None, "created_table_ids": []}

        trace.append({
            "plan": parsed.plan,
            "code": parsed.code,
            "stdout": result.get("stdout",""),
            "error": result.get("error"),
            "created_table_ids": result.get("created_table_ids", []),
            "done": parsed.done,
            "final_answer": parsed.final_answer,
        })

        if result.get("error"):
            feedback = f"""Your code raised an error.

Error:
{result.get('error')}

stdout:
{result.get('stdout')}

Fix the code and try again.
If you got a KeyError or AttributeError, print() the object to see its structure.
Do NOT repeat the same code — change your approach.
Remember tool contracts (filter_table filters must be a LIST of dicts)."""
            messages.append({"role": "assistant", "content": parsed.model_dump_json()})
            messages.append({"role": "user", "content": feedback})
            continue

        if parsed.done:
            if not (parsed.final_answer or "").strip():
                messages.append({"role": "assistant", "content": parsed.model_dump_json()})
                messages.append({"role": "user", "content": "You set done=true but final_answer is empty. Provide final_answer."})
                continue
            return {"final": parsed.final_answer, "trace": trace}

        observation = (
            f"Your code ran successfully.\n\nstdout:\n{result.get('stdout')}\n\n"
            f"tables created:\n{result.get('created_table_ids')}\n\n"
            "If you now have enough information, set done=true and provide final_answer. "
            "Otherwise, write the next code step."
        )
        messages.append({"role": "assistant", "content": parsed.model_dump_json()})
        messages.append({"role": "user", "content": observation})

    return {"final": "Reached max_steps without done=true.", "trace": trace}


# ─────────────────────────────────────────────
# Display helper (we'll reuse this everywhere)
# ─────────────────────────────────────────────

def run_and_display(
    heading_str: str,
    query: str,
    *,
    state_context: Optional[str] = None,
    history_context: Optional[str] = None,
    max_steps: int = 6,
    show_trace: bool = True,
) -> Dict[str, Any]:
    """Run the agent, display the query + answer + trace. Returns the result dict."""
    heading(heading_str, level=3)
    output_box(query, label="User", style="warning")

    result = run_code_agent(
        query,
        max_steps=max_steps,
        state_context=state_context,
        history_context=history_context,
    )

    llm_response(result["final"], label="Agent")
    if show_trace:
        render_code_trace(result["trace"])
    return result


heading("Coding agent ready", level=3)
output_box(
    "Use: res = run_and_display('Title', 'your question')\n"
    "Or:  res = run_code_agent('your question')  (no display)",
    label="✅ CodeAgent",
    style="success",
)
# Out:
# ### Coding agent ready
#     <div style="background: #F0FDF4; border-left: 4px solid #DCFCE7; padding: 12px 16px; border-radius: 4px; margin: 8px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#         <div style="font-weight: 600; color: #15803D; margin-bottom: 4px;">✅ CodeAgent</div>
#         <pre style="margin: 0; white-space: pre-wrap; font-size: 13px; line-height: 1.5; color: #374151;">Use: res = run_and_display('Title', 'your question')
# Or:  res = run_code_agent('your question')  (no display)</pre>
#     </div>

# %% [markdown]
# ## Part 0 — Recap: the Workshop 5 CodeAgent
#
# Run a single EDA query and look at the trace. This is our baseline before we add memory.

# %%
_ = set_active_table(pokemon_table_id)

question = """Create a derived metric bulkiness = (hp + defense) / speed for all Pokémon.
Then show the top 6 generations by mean bulkiness as a bar chart.
Finish with a concise takeaway.
"""

res0 = run_and_display("Baseline: single-turn query (no memory)", question, max_steps=3)
# Out:
# ### Baseline: single-turn query (no memory)
#     <div style="background: #FFFBEB; border-left: 4px solid #FEF3C7; padding: 12px 16px; border-radius: 4px; margin: 8px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#         <div style="font-weight: 600; color: #A16207; margin-bottom: 4px;">User</div>
#         <pre style="margin: 0; white-space: pre-wrap; font-size: 13px; line-height: 1.5; color: #374151;">Create a derived metric bulkiness = (hp + defense) / speed for all Pokémon.
# Then show the top 6 generations by mean bulkiness as a bar chart.
# Finish with a concise takeaway.
# </pre>
#     </div>
#     <div style="background: #EFF6FF; border-left: 4px solid #DBEAFE; padding: 12px 16px; border-radius: 4px; margin: 8px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#         <div style="font-weight: 600; color: #1D4ED8; margin-bottom: 4px;">Agent</div>
# ...

# %% [markdown]
# ## Part 1 — The memory problem
#
# In a real use-case, an analyst doesn't usually just ask one question. They ask a question, look at results, then ask a follow‑up like "now do the same, but…".
#
# Let's simulate a short conversation **without** giving the agent any chat history or session state.

# %%
# Reset store to just the base table so this demo is self-contained
store.reset(keep_base=True)
_ = set_active_table(pokemon_table_id)

turn1_q = "Filter to Fire-type Pokémon (type_1 == Fire OR type_2 == Fire), save as fire_pokemon, and tell me how many rows it has."
turn2_q = "What is the average attack of Fire-type pokemon?"

res_turn1 = run_and_display("TURN 1", turn1_q)

separator()

res_turn2_no_memory = run_and_display("TURN 2 (follow-up, no memory/state injected)", turn2_q)

separator()

heading("What to notice", level=3)
output_box(
    "Even when this seems to work, the agent is operating 'blind' across turns.\n\n"
    "Common failure modes:\n"
    "- It recomputes work from scratch instead of reusing the table from Turn 1.\n"
    "- It answers using the full Pokémon table instead of the intended subset.\n"
    "- It wastes steps calling list_tables()/describe_table() to figure out what's going on.\n\n"
    "Next: we'll explicitly provide (1) agent/session state and (2) chat history.",
    label="Observation",
    style="info",
)
# Out:
# ### TURN 1
#     <div style="background: #FFFBEB; border-left: 4px solid #FEF3C7; padding: 12px 16px; border-radius: 4px; margin: 8px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#         <div style="font-weight: 600; color: #A16207; margin-bottom: 4px;">User</div>
#         <pre style="margin: 0; white-space: pre-wrap; font-size: 13px; line-height: 1.5; color: #374151;">Filter to Fire-type Pokémon (type_1 == Fire OR type_2 == Fire), save as fire_pokemon, and tell me how many rows it has.</pre>
#     </div>
#     <div style="background: #EFF6FF; border-left: 4px solid #DBEAFE; padding: 12px 16px; border-radius: 4px; margin: 8px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#         <div style="font-weight: 600; color: #1D4ED8; margin-bottom: 4px;">Agent</div>
#         <pre style="margin: 0; white-space: pre-wrap; font-size: 13px; line-height: 1.5; color: #374151;">The fire_pokemon table has 64 rows.</pre>
#     </div>
# ...

# %% [markdown]
# ## Part 2 — Agent/session state (tables + active table)
#
# Before we even talk about chat history, we can make the agent more reliable by giving it a snapshot of **agent/session state**:
#
# - what tables exist (name, `table_id`, row counts)
# - which table is currently active
#
# This costs almost nothing (a few lines of text) and immediately helps the model reuse prior work.

# %%
def snapshot_session_state(store: AnalyticsStore, *, max_tables: int = 8) -> Dict[str, Any]:
    """Deterministic snapshot of agent/session state."""
    tables = list(store.tables.values())
    recent = tables[-max_tables:]
    return {
        "active_table_id": store.active_table_id,
        "recent_tables": [
            {"name": t.name, "table_id": t.table_id, "rows": int(t.df.shape[0]), "cols": int(t.df.shape[1])}
            for t in recent
        ],
    }

def format_session_state_for_prompt(state: Dict[str, Any]) -> str:
    active_id = state.get("active_table_id")
    lines = ["AGENT/SESSION STATE"]
    if active_id:
        active_name = next((t["name"] for t in state["recent_tables"] if t["table_id"] == active_id), None)
        if active_name:
            lines.append(f"- active_table: {active_name} ({active_id})")
        else:
            lines.append(f"- active_table_id: {active_id}")
    else:
        lines.append("- active_table: (none)")

    lines.append("- recent_tables:")
    for t in state["recent_tables"]:
        lines.append(f"  - {t['name']} -> {t['table_id']} ({t['rows']} rows, {t['cols']} cols)")
    return "\n".join(lines)


# Show what state looks like right now (after Part 1 created fire_pokemon)
state = snapshot_session_state(store, max_tables=8)
state_message = format_session_state_for_prompt(state)

heading("State message injected into the prompt", level=3)
output_box(state_message, label="state_message", style="info")
# Out:
# ### State message injected into the prompt
#     <div style="background: #EFF6FF; border-left: 4px solid #DBEAFE; padding: 12px 16px; border-radius: 4px; margin: 8px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#         <div style="font-weight: 600; color: #1D4ED8; margin-bottom: 4px;">state_message</div>
#         <pre style="margin: 0; white-space: pre-wrap; font-size: 13px; line-height: 1.5; color: #374151;">AGENT/SESSION STATE
# - active_table: pokemon (tbl_6ba85378)
# - recent_tables:
#   - pokemon -> tbl_6ba85378 (800 rows, 13 cols)
#   - fire_pokemon -> tbl_563e2f00 (64 rows, 13 cols)
#   - fire_pokemon -> tbl_1baf5e82 (64 rows, 13 cols)
#   - avg_attack_fire -> tbl_c7c6f9b8 (1 rows, 2 cols)</pre>
#     </div>

# %%
# Re-run the same follow-up, but now the model *sees* the state snapshot
res_turn2_with_state = run_and_display(
    "TURN 2 (follow-up, with agent/session state injected)",
    turn2_q,
    state_context=state_message,
)
# Out:
# ### TURN 2 (follow-up, with agent/session state injected)
#     <div style="background: #FFFBEB; border-left: 4px solid #FEF3C7; padding: 12px 16px; border-radius: 4px; margin: 8px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#         <div style="font-weight: 600; color: #A16207; margin-bottom: 4px;">User</div>
#         <pre style="margin: 0; white-space: pre-wrap; font-size: 13px; line-height: 1.5; color: #374151;">What is the average attack of Fire-type pokemon?</pre>
#     </div>
#     <div style="background: #EFF6FF; border-left: 4px solid #DBEAFE; padding: 12px 16px; border-radius: 4px; margin: 8px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#         <div style="font-weight: 600; color: #1D4ED8; margin-bottom: 4px;">Agent</div>
#         <pre style="margin: 0; white-space: pre-wrap; font-size: 13px; line-height: 1.5; color: #374151;">The average attack of Fire-type Pokémon is approximately 70.0.</pre>
# ...

# %% [markdown]
# ## Part 3 — Chat history (window / buffer)
#
# Agent/session state helps the model *find tables*, but it still doesn't capture what the user meant across turns (pronouns, references, "do the same as before").
#
# Next we'll inject a **window** of recent turns as chat history.

# %%
# A simple chat buffer that stores compact turns (question + answer, no code)
Turn = Dict[str, Any]

def format_recent_turns_for_prompt(turns: List[Turn], *, max_turns: int = 4) -> str:
    lines = ["CHAT HISTORY (RECENT):"]
    recent = turns[-max_turns:]
    for t in recent:
        lines.append(f"User: {t['user']}")
        lines.append(f"Assistant: {t['assistant']}")
        if t.get("artifacts"):
            art = "; ".join(f"{a['name']} ({a['table_id']})" for a in t["artifacts"])
            lines.append(f"Artifacts: {art}")
        lines.append("")  # spacer
    return "\n".join(lines).strip()


# Build a 2-turn history from the results we captured above
history_turns: List[Turn] = [
    {
        "user": turn1_q,
        "assistant": res_turn1["final"],
        "artifacts": [],
    },
    {
        "user": turn2_q,
        "assistant": res_turn2_with_state["final"],
        "artifacts": [],
    },
]

chat_history = format_recent_turns_for_prompt(history_turns, max_turns=4)

heading("Chat history message injected into the prompt", level=3)
output_box(chat_history, label="history_message", style="info")

separator()

# A follow-up that relies on ellipsis: "do the same"
turn3_q = "Now do the same for Water-type Pokémon and compare the average attack between Fire and Water."

# Refresh state (new tables may have been created)
state_message = format_session_state_for_prompt(snapshot_session_state(store, max_tables=8))

res_turn3 = run_and_display(
    "TURN 3 (with both session state AND chat history)",
    turn3_q,
    state_context=state_message,
    history_context=chat_history,
)
# Out:
# ### Chat history message injected into the prompt
#     <div style="background: #EFF6FF; border-left: 4px solid #DBEAFE; padding: 12px 16px; border-radius: 4px; margin: 8px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#         <div style="font-weight: 600; color: #1D4ED8; margin-bottom: 4px;">history_message</div>
#         <pre style="margin: 0; white-space: pre-wrap; font-size: 13px; line-height: 1.5; color: #374151;">CHAT HISTORY (RECENT):
# User: Filter to Fire-type Pokémon (type_1 == Fire OR type_2 == Fire), save as fire_pokemon, and tell me how many rows it has.
# Assistant: The fire_pokemon table has 64 rows.
#
# User: What is the average attack of Fire-type pokemon?
# Assistant: The average attack of Fire-type Pokémon is approximately 70.0.</pre>
#     </div>
# <hr style="border: none; border-top: 1px solid #D1D5DB; margin: 16px 0;">
# ### TURN 3 (with both session state AND chat history)
# ...

# %% [markdown]
# ## Part 4 — The scaling problem (buffer alone doesn't scale)
#
# If we keep appending chat history forever, prompts get long, slow, and expensive.
#
# A common pattern is:
# - keep the last *K* turns verbatim (buffer/window)
# - compress older turns into a running **summary**
#
# We'll implement a small summary helper and see how it reduces prompt size.

# %%
def summarize_turns(previous_summary: str, turns_to_summarize: List[Turn]) -> str:
    """Use the LLM to update a running conversation summary."""
    if not turns_to_summarize:
        return previous_summary

    transcript_lines = []
    for t in turns_to_summarize:
        transcript_lines.append(f"U: {t['user']}")
        transcript_lines.append(f"A: {t['assistant']}")
        if t.get("artifacts"):
            art = "; ".join(f"{a['name']} ({a['table_id']})" for a in t["artifacts"])
            transcript_lines.append(f"Artifacts: {art}")
        transcript_lines.append("")
    transcript = "\n".join(transcript_lines).strip()

    system = """You are updating a running conversation summary for an analytics assistant.
Keep the summary short and factual (max ~120 words).
Prioritize:
- what tables were created and what they represent
- key findings/numbers (only if present)
- the user's current goal / direction
Avoid:
- speculative claims
- implementation details (no code)"""

    user_msg = f"""PREVIOUS SUMMARY (may be empty):
{previous_summary}

NEW TURNS TO INCORPORATE:
{transcript}

Return an updated SUMMARY only."""

    resp = client.responses.create(
        model=MODEL,
        input=[{"role": "developer", "content": system}, {"role": "user", "content": user_msg}],
        temperature=0,
    )
    return resp.output_text.strip()


def format_summary_history_for_prompt(summary: str, recent_turns: List[Turn]) -> str:
    parts = []
    parts.append("CHAT HISTORY SUMMARY")
    parts.append(summary.strip() if summary.strip() else "(empty)")
    parts.append("")
    parts.append(format_recent_turns_for_prompt(recent_turns, max_turns=len(recent_turns)))
    return "\n".join(parts).strip()


# ─── Demonstrate the size savings ───

toy_turns: List[Turn] = [
    {"user": "Filter Fire types and save as fire_pokemon.", "assistant": "Created fire_pokemon table.", "artifacts": [{"name":"fire_pokemon","table_id":"tbl_x1"}]},
    {"user": "Average attack of those?", "assistant": "Computed mean attack for fire_pokemon.", "artifacts": []},
    {"user": "Do the same for Water and compare.", "assistant": "Created water_pokemon and compared means.", "artifacts": [{"name":"water_pokemon","table_id":"tbl_x2"}]},
    {"user": "Now only Legendary.", "assistant": "Filtered legendary subsets and recomputed.", "artifacts": [{"name":"fire_legendary","table_id":"tbl_x3"}]},
    {"user": "Plot distributions of speed.", "assistant": "Plotted histograms for speed.", "artifacts": []},
    {"user": "Which generation is bulkiest?", "assistant": "Computed bulkiness and plotted top generations.", "artifacts": [{"name":"pokemon_with_bulkiness","table_id":"tbl_x4"}]},
]

buffer_only = format_recent_turns_for_prompt(toy_turns, max_turns=len(toy_turns))
heading("Buffer-only history size", level=3)
output_box(f"{len(buffer_only)} characters\n\n{buffer_only}", label="buffer_only", style="info")

separator()

# Summarize older turns; keep last 2 verbatim
previous_summary = ""
older = toy_turns[:-2]
recent = toy_turns[-2:]

summary_text = summarize_turns(previous_summary, older)
summary_plus_recent = format_summary_history_for_prompt(summary_text, recent)

heading("Summary + recent turns size", level=3)
output_box(f"{len(summary_plus_recent)} characters\n\n{summary_plus_recent}", label="summary + recent", style="success")
# Out:
# ### Buffer-only history size
#     <div style="background: #EFF6FF; border-left: 4px solid #DBEAFE; padding: 12px 16px; border-radius: 4px; margin: 8px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#         <div style="font-weight: 600; color: #1D4ED8; margin-bottom: 4px;">buffer_only</div>
#         <pre style="margin: 0; white-space: pre-wrap; font-size: 13px; line-height: 1.5; color: #374151;">687 characters
#
# CHAT HISTORY (RECENT):
# User: Filter Fire types and save as fire_pokemon.
# Assistant: Created fire_pokemon table.
# Artifacts: fire_pokemon (tbl_x1)
#
# User: Average attack of those?
# Assistant: Computed mean attack for fire_pokemon.
#
# User: Do the same for Water and compare.
# Assistant: Created water_pokemon and compared means.
# Artifacts: water_pokemon (tbl_x2)
#
# User: Now only Legendary.
# Assistant: Filtered legendary subsets and recomputed.
# Artifacts: fire_legendary (tbl_x3)
#
# User: Plot distributions of speed.
# ...

# %% [markdown]
# ## Part 5 — The explicit multi-turn loop
#
# We'll keep it simple and explicit:
#
# - Build a **state message** from the current store
# - Build a **history message** (summary + recent turns)
# - Run the agent loop
# - Update history (and occasionally summarize older turns)
#
# This is the core pattern you can reuse for any conversational agent.

# %%
def snapshot_tables(store: AnalyticsStore) -> Dict[str, Dict[str, Any]]:
    """Snapshot table IDs for diffing before/after a turn."""
    return {
        tid: {"table_id": tid, "name": t.name, "rows": int(t.df.shape[0]), "cols": int(t.df.shape[1])}
        for tid, t in store.tables.items()
    }

def new_tables_since(before: Dict, after: Dict) -> List[Dict[str, Any]]:
    return [after[tid] for tid in after if tid not in before]


# ─── Conversational memory state ───

chat_summary = ""                   # compressed older history
recent_turns: List[Turn] = []      # last K turns verbatim
KEEP_LAST_TURNS = 3

def build_history_message() -> str:
    if chat_summary.strip():
        return format_summary_history_for_prompt(chat_summary, recent_turns)
    if recent_turns:
        return format_recent_turns_for_prompt(recent_turns, max_turns=len(recent_turns))
    return "CHAT HISTORY (RECENT)\n(empty)"

def add_turn_to_history(turn: Turn) -> None:
    global chat_summary, recent_turns
    recent_turns.append(turn)

    # When buffer exceeds KEEP_LAST_TURNS, summarize the overflow
    if len(recent_turns) > KEEP_LAST_TURNS:
        to_summarize = recent_turns[:-KEEP_LAST_TURNS]
        chat_summary = summarize_turns(chat_summary, to_summarize)
        recent_turns = recent_turns[-KEEP_LAST_TURNS:]


# ─── Run a 5-turn conversation ───

store.reset(keep_base=True)
_ = set_active_table(pokemon_table_id)

conversation = [
    "Filter to Fire-type Pokémon (type_1 == Fire OR type_2 == Fire), save as fire_pokemon.",
    "What is the average attack of those?",
    "Now do the same for Water-type Pokémon and compare the average attack between Fire and Water.",
    "Now restrict BOTH subsets to Legendary only and compare average attack again.",
    "Plot histograms of speed for Fire Legendary vs Water Legendary and give a takeaway.",
]

for i, q in enumerate(conversation, start=1):
    before = snapshot_tables(store)

    state_msg = format_session_state_for_prompt(snapshot_session_state(store, max_tables=8))
    history_msg = build_history_message()

    heading(f"TURN {i}", level=3)
    output_box(q, label="User", style="warning")
    output_box(f"{state_msg}\n\n{history_msg}", label="Prompt context", style="info")

    try:
        res = run_code_agent(
            q,
            max_steps=6,
            state_context=state_msg,
            history_context=history_msg,
        )
    except Exception as exc:
        output_box(f"Agent error: {exc}", label="⚠️ Error", style="error")
        res = {"final": f"(Error: {exc})", "trace": []}

    llm_response(res["final"], label="Agent")
    render_code_trace(res["trace"])

    after = snapshot_tables(store)
    artifacts = new_tables_since(before, after)

    add_turn_to_history({
        "user": q,
        "assistant": res["final"],
        "artifacts": artifacts,
    })
    separator()


heading("Current chat summary", level=3)
output_box(chat_summary or "(empty)", label="chat_summary", style="info")

heading("Recent turns kept verbatim", level=3)
output_box(format_recent_turns_for_prompt(recent_turns, max_turns=len(recent_turns)), label="recent_turns", style="info")
# Out:
# ### TURN 1
#     <div style="background: #FFFBEB; border-left: 4px solid #FEF3C7; padding: 12px 16px; border-radius: 4px; margin: 8px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#         <div style="font-weight: 600; color: #A16207; margin-bottom: 4px;">User</div>
#         <pre style="margin: 0; white-space: pre-wrap; font-size: 13px; line-height: 1.5; color: #374151;">Filter to Fire-type Pokémon (type_1 == Fire OR type_2 == Fire), save as fire_pokemon.</pre>
#     </div>
#     <div style="background: #EFF6FF; border-left: 4px solid #DBEAFE; padding: 12px 16px; border-radius: 4px; margin: 8px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#         <div style="font-weight: 600; color: #1D4ED8; margin-bottom: 4px;">Prompt context</div>
#         <pre style="margin: 0; white-space: pre-wrap; font-size: 13px; line-height: 1.5; color: #374151;">AGENT/SESSION STATE
# - active_table: pokemon (tbl_6ba85378)
# - recent_tables:
# ...

# %% [markdown]
# ## Part 6 — Long-term memory (concept + tiny persistence demo)
#
# **Long-term memory** means information that persists across sessions.
#
# For an analytics assistant, examples include:
# - user preferences (e.g., "prefer median", "always show charts")
# - dataset metadata / data dictionary
# - a short "what we did last time" session summary
#
# Below is a tiny persistence demo: we save the session summary to disk and show how you'd load it in a future session.

# %%
LT_MEMORY_PATH = Path("workshop6_long_term_memory.json")

long_term_memory = {
    "dataset": str(DATA_PATH),
    "session_summary": chat_summary,
    "saved_at": pd.Timestamp.now().isoformat(),
}

LT_MEMORY_PATH.write_text(json.dumps(long_term_memory, indent=2))
output_box(f"Saved: {LT_MEMORY_PATH.resolve()}", label="✅ Persisted", style="success")

# Load it back (simulating a future run)
loaded = json.loads(LT_MEMORY_PATH.read_text())
heading("Loaded long-term memory", level=3)
output_box(_safe_json(loaded), label="long_term_memory.json", style="info")
# Out:
#     <div style="background: #F0FDF4; border-left: 4px solid #DCFCE7; padding: 12px 16px; border-radius: 4px; margin: 8px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#         <div style="font-weight: 600; color: #15803D; margin-bottom: 4px;">✅ Persisted</div>
#         <pre style="margin: 0; white-space: pre-wrap; font-size: 13px; line-height: 1.5; color: #374151;">Saved: /home/jupyter-skarki/build-fellowship-ai-assistant/notebooks/workshop6_long_term_memory.json</pre>
#     </div>
# ### Loaded long-term memory
#     <div style="background: #EFF6FF; border-left: 4px solid #DBEAFE; padding: 12px 16px; border-radius: 4px; margin: 8px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#         <div style="font-weight: 600; color: #1D4ED8; margin-bottom: 4px;">long_term_memory.json</div>
#         <pre style="margin: 0; white-space: pre-wrap; font-size: 13px; line-height: 1.5; color: #374151;">{
# ...

# %%
lt_context = f"""
LONG-TERM MEMORY (previous session)

{loaded["session_summary"]}
""".strip()

heading("History we would inject next session", level=3)
output_box(lt_context, label="lt_context", style="info")
# Out:
# ### History we would inject next session
#     <div style="background: #EFF6FF; border-left: 4px solid #DBEAFE; padding: 12px 16px; border-radius: 4px; margin: 8px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#         <div style="font-weight: 600; color: #1D4ED8; margin-bottom: 4px;">lt_context</div>
#         <pre style="margin: 0; white-space: pre-wrap; font-size: 13px; line-height: 1.5; color: #374151;">LONG-TERM MEMORY (previous session)
#
# **SUMMARY:** A new table, 'fire_pokemon', has been created, containing 64 rows that represent Fire-type Pokémon (either type_1 or type_2 is Fire). The average attack of these Fire-type Pokémon is 84.11. The user's current goal is to analyze this subset of Pokémon.</pre>
#     </div>

# %%
followup = (
    "Continue from last session. We previously computed average attack for Fire-type Pokémon. "
    "Now compute the average attack for Water-type Pokémon, and compare Fire vs Water "
    "in one concise takeaway."
)

# Simulate a fresh session: reset store, no history
store.reset(keep_base=True)
_ = set_active_table(pokemon_table_id)

res_no_lt = run_and_display(
    "WITHOUT long-term memory",
    followup,
    max_steps=5,
)

separator()

res_with_lt = run_and_display(
    "WITH long-term memory injected",
    followup,
    max_steps=5,
    history_context=lt_context,
)
# Out:
# ### WITHOUT long-term memory
#     <div style="background: #FFFBEB; border-left: 4px solid #FEF3C7; padding: 12px 16px; border-radius: 4px; margin: 8px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#         <div style="font-weight: 600; color: #A16207; margin-bottom: 4px;">User</div>
#         <pre style="margin: 0; white-space: pre-wrap; font-size: 13px; line-height: 1.5; color: #374151;">Continue from last session. We previously computed average attack for Fire-type Pokémon. Now compute the average attack for Water-type Pokémon, and compare Fire vs Water in one concise takeaway.</pre>
#     </div>
#     <div style="background: #EFF6FF; border-left: 4px solid #DBEAFE; padding: 12px 16px; border-radius: 4px; margin: 8px 0; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;">
#         <div style="font-weight: 600; color: #1D4ED8; margin-bottom: 4px;">Agent</div>
# ...

# %% [markdown]
# ### Capabilities enabled by Memory
#
# **Without any memory**:
# - ✅ Planning and execution within a single query
# - ✅ Self-correcting based on observations
# - ❌ Can't reuse artifacts/state from previous queries
# - ❌ Can't build on previous conversations
# - ❌ Can't remember user choices/preferences over the long term (across sessions)
#
# **With Agent/Session State**:
# - ✅ Planning and execution within a single query
# - ✅ Self-correcting based on observations
# - ✅ Can reuse artifacts/state from previous queries
# - ❌ Can't build on previous conversations
# - ❌ Can't remember user choices/preferences over the long term (across sessions)
#
# **With Agent/Session State + Chat History**:
# - ✅ Planning and execution within a single query
# - ✅ Self-correcting based on observations
# - ✅ Can reuse artifacts/state from previous queries
# - ✅ Can build on previous conversations
# - ❌ Can't remember user choices/preferences over the long term (across sessions)
#
# **With Agent/Session State + Chat History + Long-Term Memory**:
# - ✅ Planning and execution within a single query
# - ✅ Self-correcting based on observations
# - ✅ Can reuse artifacts/state from previous queries
# - ✅ Can build on previous conversations
# - ✅ Can remember user choices/preferences over the long term (across sessions)

# %% [markdown]
# ## Part 7 — Pitfalls & best practices
#
# ### Chat history
# - **Bloat:** don't keep full chat forever → use summary + recent-window, or pass only relevant episodes.
# - **Summary drift:** summaries can lose or distort details → keep them short and factual.
#
# ### Agent/session state
# - **State drift:** active table can change unexpectedly (e.g., after intermediate aggregations). Inject state each turn so the model can re-ground.
# - **Ambiguity:** table names can collide → always show both *name* and *table_id* in state messages.
#
# ### Long-term memory
# - **Privacy:** don't persist sensitive data by default; decide what you retain and for how long.
# - **Poisoning:** don't store unverified claims as facts; store grounded artifacts (tables created, summaries of actions).
# - **Reset semantics:** be explicit about "new session" (clear chat history, optionally clear derived tables, keep base dataset).
